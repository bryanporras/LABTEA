# %%
# IMPORTANDO LIBRERIAS Y MATPLOTLIB

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
#SUBIENDO FUENTE DE DATOS

# %%
data = pd.read_csv("prueba.csv")

# %%
data
# Out:
#     Sector  Grupo  Sendero  Distancia (m)  Parcela  Árbol    Especie  \
# 0        I      1        2            150        1      1     Encino
# 1        I      1        2            150        1      2     Encino
# 2        I      1        2            150        1      3      Roble
# 3        I      1        2            150        1      4      Nance
# 4        I      1        2            150        1      5      Roble
# ..     ...    ...      ...            ...      ...    ...        ...
# 520    III     10       26             10        5      9     Encino
# 521    III     10       26             10        5     10     Carbón
# 522    III     10       26             10        5     11     Carbón
# 523    III     10       26             10        5     12     Encino
# 524    III     10       26             10        5     13  Molinillo
#
#      DAP (cm)  HT (m)  HC (m)  LD   AB (m2)
# 0         5.1    4.91  1.7900   0  0.002043
# 1         9.4    7.77  3.0700   0  0.006940
# ...

# %%
# ploteando datos

# %%
ig, ax = plt.subplots()
spc = data.Especie
Dap= data.Grupo
ax.barh(spc, Dap)

ax.set(xlabel = "Grupo", ylabel = "Arbol", title = "Arboles segun grupo")

plt.show()
